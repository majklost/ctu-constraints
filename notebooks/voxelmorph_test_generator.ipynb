# %% [markdown]
# # Experiment - Voxelmorph on deformed masks
# - with MSE loss and grad - on one hot encoded masks

# %%
# %load_ext autoreload
# %autoreload 2
from constraints.voxelmorph.models import VxmPairwise
from constraints.generators import ArteryGeneratorDeformed
from constraints.visu import show_torch_image
import pytorch_lightning as pl
import neurite as ne

# %%
from IPython.display import Image, display
import numpy as np
from PIL import Image as PILImage

arr = (np.random.rand(128,128)*255).astype("uint8")
img = PILImage.fromarray(arr)

display(img)
# Out:
# <PIL.Image.Image image mode=L size=128x128>

# %%
import torch
import torchvision
import torchvision.transforms.v2 as T
import matplotlib.pyplot as plt
import numpy as np
import neurite as ne
from torch import nn
import tqdm

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
dataset_trn = ArteryGeneratorDeformed(num_samples=1000, fixed_seed=42, magnitude=5.0, integrations=0, fractal_mode="upsample")
dataset_val = ArteryGeneratorDeformed(num_samples=100, fixed_seed=43, magnitude=5.0, integrations=0, fractal_mode="upsample")
# Out:
# Using device: cuda

# %%
# Sanity check: visualize a few samples from the dataset
sample = dataset_trn[0]
img, mask, template = sample["img"], sample["mask"], sample["template"]
field = sample["field"]
show_torch_image(img, title="Deformed Image", cmap="gray")
show_torch_image(mask, title="Deformed Mask", cmap="gray")
show_torch_image(template, title="Template Image", cmap="gray")
print("Shapes:")
print(f"Image: {img.shape}")
print(f"Mask: {mask.shape}")
print(f"Template: {template.shape}")
# Out:
# Shapes:
# Image: torch.Size([1, 256, 256])
# Mask: torch.Size([3, 256, 256])
# Template: torch.Size([3, 256, 256])

# %%
class LitVoxelMorph(pl.LightningModule):
    def __init__(self,grad_loss_weight=0.05):
        super().__init__()
        self.model  = VxmPairwise(
            ndim=2,
            source_channels=3,
            target_channels=3,
            nb_features=[
            [32, 32, 32, 32], # encoder features
            [32, 32, 32, 32]])  # decoder features
        self.image_loss_fn = torch.nn.MSELoss()
        self.grad_loss_fn = ne.nn.modules.SpatialGradient('l2')
        self.grad_loss_weight = grad_loss_weight

    def forward(self, source,target,return_warped_source=True,return_field_type='displacement',return_warped_target=False):
        return self.model(source,target,return_warped_source=return_warped_source,return_field_type=return_field_type,return_warped_target=return_warped_target)

    def _shared_step(self, batch,stage):
        template = batch["template"]
        mask = batch["mask"]
        pred_field, warped_source = self(template, mask, return_warped_source=True, return_field_type='displacement')
        image_loss = self.image_loss_fn(warped_source,mask)
        grad_loss = self.grad_loss_fn(pred_field)
        batch_size = mask.size(0)
        loss = image_loss + self.grad_loss_weight * grad_loss
        self.log(f'{stage}_loss', loss, on_step=False, on_epoch=True, prog_bar=True, batch_size=batch_size)
        self.log(f'{stage}_image_loss', image_loss, on_step=False, on_epoch=True, batch_size=batch_size)
        self.log(f'{stage}_grad_loss', grad_loss, on_step=False, on_epoch=True, batch_size=batch_size)
        return loss
    
    def training_step(self, batch, batch_idx):
        return self._shared_step(batch, 'train')

    def validation_step(self, batch, batch_idx):
        return self._shared_step(batch, 'val')

    def predict_step(self, batch, batch_idx, dataloader_idx=0):
        template = batch["template"]
        mask = batch["mask"]
        pred_field, warped_source = self(template, mask, return_warped_source=True, return_field_type='displacement')
        return {
            "mask": mask,
            "template": template,
            "pred_field": pred_field,
            "warped_source": warped_source,
        }

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=1e-4)

# %% [markdown]
# ## Deformation only

# %%
EPOCHS = 50
from lightning.pytorch.loggers import CSVLogger
from pathlib import Path

ckpt_path = Path('notebooks/checkpoints/voxelmorph_test_generator/lit_voxelmorph_latest.ckpt')

logger = CSVLogger('logs', name='experiment')
model = LitVoxelMorph()

# Multiprocessing workers can stall in some Jupyter/cluster setups; start with 0 for reliability.
trn_loader = torch.utils.data.DataLoader(
    dataset_trn,
    batch_size=32,
    shuffle=True,
    num_workers=2,
    pin_memory=True,
)
val_loader = torch.utils.data.DataLoader(
    dataset_val,
    batch_size=32,
    shuffle=False,
    num_workers=2,
    pin_memory=True,
)

trainer = pl.Trainer(
    max_epochs=EPOCHS,
    accelerator='auto',
    devices='auto',
    logger=logger,
    enable_progress_bar=True,
    enable_checkpointing=False,
    log_every_n_steps=1,
    num_sanity_val_steps=0,
    profiler='simple',
)

trainer.fit(
    model,
    train_dataloaders=trn_loader,
    val_dataloaders=val_loader,
    ckpt_path=ckpt_path if ckpt_path.exists() else None,
)
# Out:
# /mnt/appl/software/PyTorch-Lightning/2.5.5-foss-2025a-CUDA-12.8.0/lib/python3.13/site-packages/lightning_fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /home/mrkosmic/.local/lib/python3.13/site-packages/i ...
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type            | Params | Mode
# ----------------------------------------------------------
# 0 | model         | VxmPairwise     | 112 K  | train
# 1 | image_loss_fn | MSELoss         | 0      | train
# 2 | grad_loss_fn  | SpatialGradient | 0      | train
# ----------------------------------------------------------
# 112 K     Trainable params
# 0         Non-trainable params
# 112 K     Total params
# 0.451     Total estimated model params size (MB)
# 73        Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# FIT Profiler Report
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                      	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                       	|  -              	|  51572          	|  194.8          	|  100 %          	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                          	|  3.8874         	|  50             	|  194.37         	|  99.776         	|
# |  [_TrainingEpochLoop].train_dataloader_next                  	|  0.053095       	|  1600           	|  84.953         	|  43.609         	|
# |  run_training_batch                                          	|  0.047335       	|  1600           	|  75.737         	|  38.878         	|
# |  [LightningModule]LitVoxelMorph.optimizer_step               	|  0.047226       	|  1600           	|  75.562         	|  38.788         	|
# |  [Strategy]SingleDeviceStrategy.training_step                	|  0.040667       	|  1600           	|  65.068         	|  33.402         	|
# |  [_EvaluationLoop].val_next                                  	|  0.079501       	|  200            	|  15.9           	|  8.1621         	|
# |  [Strategy]SingleDeviceStrategy.backward                     	|  0.0049371      	|  1600           	|  7.8993         	|  4.055          	|
# |  [Strategy]SingleDeviceStrategy.validation_step              	|  0.021772       	|  200            	|  4.3544         	|  2.2353         	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                	|  0.0015416      	|  1600           	|  2.4665         	|  1.2661         	|
# |  [Callback]TQDMProgressBar.on_validation_start               	|  0.017053       	|  50             	|  0.85266        	|  0.4377         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device              	|  0.00028014     	|  1800           	|  0.50425        	|  0.25885        	|
# |  [LightningModule]LitVoxelMorph.transfer_batch_to_device     	|  0.00022009     	|  1800           	|  0.39617        	|  0.20337        	|
# |  [LightningModule]LitVoxelMorph.optimizer_zero_grad          	|  0.00021467     	|  1600           	|  0.34347        	|  0.17632        	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end           	|  0.00056775     	|  200            	|  0.11355        	|  0.058289       	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start         	|  0.00027136     	|  200            	|  0.054273       	|  0.02786        	|
# |  [Callback]TQDMProgressBar.on_validation_end                 	|  0.0010171      	|  50             	|  0.050855       	|  0.026106       	|
# |  [LightningModule]LitVoxelMorph.configure_gradient_clipping  	|  2.7246e-05     	|  1600           	|  0.043594       	|  0.022378       	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start              	|  0.00062969     	|  50             	|  0.031485       	|  0.016162       	|
# |  [LightningModule]LitVoxelMorph.on_validation_model_eval     	|  0.00059795     	|  50             	|  0.029898       	|  0.015348       	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                	|  0.00054037     	|  50             	|  0.027019       	|  0.01387        	|
# |  [Callback]TQDMProgressBar.on_train_start                    	|  0.023953       	|  1              	|  0.023953       	|  0.012296       	|
# |  [LightningModule]LitVoxelMorph.on_validation_model_zero_grad	|  0.00039164     	|  50             	|  0.019582       	|  0.010052       	|
# |  [Callback]TQDMProgressBar.on_after_backward                 	|  3.615e-06      	|  1600           	|  0.005784       	|  0.0029691      	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad               	|  3.5238e-06     	|  1600           	|  0.005638       	|  0.0028942      	|
# |  [Callback]ModelSummary.on_train_batch_end                   	|  3.3465e-06     	|  1600           	|  0.0053545      	|  0.0027486      	|
# |  [LightningModule]LitVoxelMorph.on_before_batch_transfer     	|  2.7504e-06     	|  1800           	|  0.0049507      	|  0.0025414      	|
# |  [Callback]ModelSummary.on_train_batch_start                 	|  2.7635e-06     	|  1600           	|  0.0044216      	|  0.0022698      	|
# |  [Callback]TQDMProgressBar.on_train_batch_start              	|  2.695e-06      	|  1600           	|  0.004312       	|  0.0022135      	|
# |  [Callback]TQDMProgressBar.on_before_backward                	|  2.4395e-06     	|  1600           	|  0.0039032      	|  0.0020037      	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step          	|  2.204e-06      	|  1600           	|  0.0035264      	|  0.0018102      	|
# |  [Callback]ModelSummary.on_before_optimizer_step             	|  2.0556e-06     	|  1600           	|  0.0032889      	|  0.0016883      	|
# |  [Callback]ModelSummary.on_before_backward                   	|  2.041e-06      	|  1600           	|  0.0032656      	|  0.0016764      	|
# |  [LightningModule]LitVoxelMorph.on_after_batch_transfer      	|  1.6582e-06     	|  1800           	|  0.0029848      	|  0.0015322      	|
# |  [Callback]ModelSummary.on_after_backward                    	|  1.7007e-06     	|  1600           	|  0.0027211      	|  0.0013969      	|
# |  [Callback]ModelSummary.on_before_zero_grad                  	|  1.6516e-06     	|  1600           	|  0.0026426      	|  0.0013565      	|
# |  [LightningModule]LitVoxelMorph.on_before_zero_grad          	|  1.6171e-06     	|  1600           	|  0.0025874      	|  0.0013282      	|
# |  [LightningModule]LitVoxelMorph.on_train_batch_start         	|  1.5891e-06     	|  1600           	|  0.0025426      	|  0.0013052      	|
# |  [LightningModule]LitVoxelMorph.on_train_batch_end           	|  1.4988e-06     	|  1600           	|  0.0023982      	|  0.0012311      	|
# |  [LightningModule]LitVoxelMorph.on_after_backward            	|  1.4376e-06     	|  1600           	|  0.0023002      	|  0.0011808      	|
# |  [LightningModule]LitVoxelMorph.on_before_backward           	|  1.3413e-06     	|  1600           	|  0.0021461      	|  0.0011017      	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start         	|  1.317e-06      	|  1600           	|  0.0021072      	|  0.0010817      	|
# |  [LightningModule]LitVoxelMorph.on_before_optimizer_step     	|  1.2579e-06     	|  1600           	|  0.0020127      	|  0.0010332      	|
# |  [Callback]ModelSummary.on_fit_start                         	|  0.0013996      	|  1              	|  0.0013996      	|  0.00071846     	|
# |  [Callback]ModelSummary.on_validation_batch_end              	|  2.7308e-06     	|  200            	|  0.00054616     	|  0.00028037     	|
# |  [Callback]ModelSummary.on_validation_batch_start            	|  1.8798e-06     	|  200            	|  0.00037597     	|  0.000193       	|
# |  [Callback]ModelSummary.on_validation_start                  	|  7.5055e-06     	|  50             	|  0.00037528     	|  0.00019264     	|
# |  [Callback]ModelSummary.on_train_epoch_start                 	|  7.322e-06      	|  50             	|  0.0003661      	|  0.00018793     	|
# |  [Callback]TQDMProgressBar.on_train_end                      	|  0.00035163     	|  1              	|  0.00035163     	|  0.0001805      	|
# |  [LightningModule]LitVoxelMorph.on_validation_start          	|  5.4157e-06     	|  50             	|  0.00027079     	|  0.000139       	|
# |  [LightningModule]LitVoxelMorph.on_validation_batch_start    	|  1.2909e-06     	|  200            	|  0.00025818     	|  0.00013253     	|
# |  [LightningModule]LitVoxelMorph.on_validation_batch_end      	|  1.2417e-06     	|  200            	|  0.00024835     	|  0.00012749     	|
# |  [LightningModule]LitVoxelMorph.configure_optimizers         	|  0.00023926     	|  1              	|  0.00023926     	|  0.00012282     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start          	|  4.7466e-06     	|  50             	|  0.00023733     	|  0.00012183     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end           	|  2.5591e-06     	|  50             	|  0.00012796     	|  6.5685e-05     	|
# |  [Callback]ModelSummary.on_validation_end                    	|  2.2387e-06     	|  50             	|  0.00011193     	|  5.746e-05      	|
# |  [Callback]ModelSummary.on_train_epoch_end                   	|  2.1227e-06     	|  50             	|  0.00010613     	|  5.4482e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start         	|  1.9024e-06     	|  50             	|  9.5122e-05     	|  4.883e-05      	|
# |  [LightningModule]LitVoxelMorph.on_validation_epoch_start    	|  1.4953e-06     	|  50             	|  7.4763e-05     	|  3.8379e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_start            	|  1.4047e-06     	|  50             	|  7.0233e-05     	|  3.6053e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end            	|  1.1817e-06     	|  50             	|  5.9087e-05     	|  3.0332e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_end              	|  1.176e-06      	|  50             	|  5.8799e-05     	|  3.0184e-05     	|
# |  [LightningModule]LitVoxelMorph.on_validation_end            	|  1.1372e-06     	|  50             	|  5.6858e-05     	|  2.9187e-05     	|
# |  [LightningModule]LitVoxelMorph.on_validation_epoch_end      	|  1.0893e-06     	|  50             	|  5.4464e-05     	|  2.7958e-05     	|
# |  [LightningModule]LitVoxelMorph.on_train_epoch_start         	|  1.0408e-06     	|  50             	|  5.2041e-05     	|  2.6715e-05     	|
# |  [LightningModule]LitVoxelMorph.on_train_epoch_end           	|  9.8956e-07     	|  50             	|  4.9478e-05     	|  2.5399e-05     	|
# |  [Callback]ModelSummary.on_train_start                       	|  9.404e-06      	|  1              	|  9.404e-06      	|  4.8274e-06     	|
# |  [Callback]TQDMProgressBar.setup                             	|  5.854e-06      	|  1              	|  5.854e-06      	|  3.0051e-06     	|
# |  [LightningModule]LitVoxelMorph.on_train_start               	|  4.785e-06      	|  1              	|  4.785e-06      	|  2.4563e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_end                        	|  3.796e-06      	|  1              	|  3.796e-06      	|  1.9486e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_start                      	|  2.318e-06      	|  1              	|  2.318e-06      	|  1.1899e-06     	|
# |  [LightningModule]LitVoxelMorph.configure_callbacks          	|  2.307e-06      	|  1              	|  2.307e-06      	|  1.1843e-06     	|
# |  [Callback]ModelSummary.setup                                	|  1.874e-06      	|  1              	|  1.874e-06      	|  9.6199e-07     	|
# |  [Callback]ModelSummary.on_train_end                         	|  1.818e-06      	|  1              	|  1.818e-06      	|  9.3324e-07     	|
# |  [Callback]TQDMProgressBar.teardown                          	|  1.782e-06      	|  1              	|  1.782e-06      	|  9.1478e-07     	|
# |  [LightningModule]LitVoxelMorph.setup                        	|  1.762e-06      	|  1              	|  1.762e-06      	|  9.045e-07      	|
# |  [Strategy]SingleDeviceStrategy.on_train_start               	|  1.599e-06      	|  1              	|  1.599e-06      	|  8.2081e-07     	|
# |  [Callback]ModelSummary.on_fit_end                           	|  1.306e-06      	|  1              	|  1.306e-06      	|  6.7042e-07     	|
# |  [LightningModule]LitVoxelMorph.on_fit_start                 	|  1.293e-06      	|  1              	|  1.293e-06      	|  6.6376e-07     	|
# |  [LightningModule]LitVoxelMorph.teardown                     	|  1.199e-06      	|  1              	|  1.199e-06      	|  6.155e-07      	|
# |  [Callback]ModelSummary.teardown                             	|  1.011e-06      	|  1              	|  1.011e-06      	|  5.1899e-07     	|
# |  [LightningModule]LitVoxelMorph.on_train_end                 	|  8.7102e-07     	|  1              	|  8.7102e-07     	|  4.4713e-07     	|
# |  [LightningModule]LitVoxelMorph.on_fit_end                   	|  8.06e-07       	|  1              	|  8.06e-07       	|  4.1375e-07     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                 	|  6.8999e-07     	|  1              	|  6.8999e-07     	|  3.542e-07      	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from pathlib import Path
import torch

save_dir = Path('notebooks/checkpoints/voxelmorph_test_generator')
save_dir.mkdir(parents=True, exist_ok=True)

weights_path = save_dir / 'lit_voxelmorph_latest.pt'
torch.save(model.state_dict(), weights_path)
print(f'Saved model weights to: {weights_path.resolve()}')

ckpt_path = save_dir / 'lit_voxelmorph_latest.ckpt'
if 'trainer' in globals():
    trainer.save_checkpoint(str(ckpt_path))
    print(f'Saved Lightning checkpoint to: {ckpt_path.resolve()}')
else:
    print('Trainer not found in globals(); skipped .ckpt save.')
# Out:
# Saved model weights to: /mnt/personal/mrkosmic/synced/constraints/notebooks/checkpoints/voxelmorph_test_generator/lit_voxelmorph_latest.pt
# Saved Lightning checkpoint to: /mnt/personal/mrkosmic/synced/constraints/notebooks/checkpoints/voxelmorph_test_generator/lit_voxelmorph_latest.ckpt

# %%
from pathlib import Path
save_dir = Path("./notebooks/outputs/voxelmorph_test_generator")
save_dir.mkdir(parents=True, exist_ok=True)
# device = "cuda" if torch.cuda.is_available() else "cpu"
model.eval().to('cpu')
for ex_id in range(10):
    example = dataset_val[ex_id]
    img = example['img'].cpu()
    mask = example['mask'].cpu()
    template = example['template'].cpu()
    with torch.no_grad():
        pred_field, warped_source = model(mask.unsqueeze(0), template.unsqueeze(0), return_warped_source=True, return_field_type='displacement')
    show_torch_image(mask.cpu(), title="Deformed Mask", cmap="gray", save_path=save_dir / f"example_{ex_id}_deformed_mask.png")
    show_torch_image(warped_source.cpu(), title="Warped Mask", cmap="gray", save_path=save_dir / f"example_{ex_id}_warped_mask.png")
    if ex_id == 0:
        show_torch_image(template.cpu(), title="Template Mask", cmap="gray", save_path=save_dir / f"example_{ex_id}_template_mask.png")
