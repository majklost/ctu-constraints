# %% [markdown]
# # Testing technical connections

# %%
import matplotlib.pyplot as plt
print("TEST")
import torch
# Out:
# TEST

# %%
# 1. Generate some dummy data and logs
from torch.utils.tensorboard import SummaryWriter
import numpy as np
import time
from constraints import LOGS_DIR, show_torch_image

# writer = SummaryWriter(LOGS_DIR / 'pytorch_experiment')

# for epoch in range(50):
#     # Simulate a decreasing loss
#     dummy_loss = 1.0 / (epoch + 1) + np.random.normal(0, 0.05)
#     writer.add_scalar('Loss/train', dummy_loss, epoch)
#     time.sleep(0.1)

# writer.close()
print(torch.cuda.is_available())
# Out:
# True

# %%
torch_image = torch.rand(3, 100, 100)  # Random image
show_torch_image(torch_image)
