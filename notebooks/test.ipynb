# %%
import sys
import os
import torch
import pytorch3d

print("--- System Environment Validation ---")
print(f"Python Executable Path: {sys.executable}")
print(f"Current Working Directory: {os.getcwd()}")
print(f"Is CUDA Accelerated GPU Active? {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU Device Target Name: {torch.cuda.get_device_name(0)}")
    
print(f"PyTorch3D Source Location: {pytorch3d.__file__}")
# Out:
# --- System Environment Validation ---
# Python Executable Path: /mnt/personal/mrkosmic/synced/constraints/.venv/bin/python
# Current Working Directory: /mnt/personal/mrkosmic/synced/constraints
# Is CUDA Accelerated GPU Active? True
# GPU Device Target Name: NVIDIA A100-SXM4-40GB
# PyTorch3D Source Location: /mnt/appl/software/PyTorch3D/0.7.9-foss-2025a-CUDA-12.8.0/lib/python3.13/site-packages/pytorch3d/__init__.py
